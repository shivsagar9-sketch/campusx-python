# %% [markdown]
# <a href="https://colab.research.google.com/github/shivsagar9-sketch/campusx-python/blob/main/session_1_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data","Science","Mentorship","Program",sep='-',end='-started-')
print("By","CampusX",sep='-')

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
tem = float(input("enter a temperature in the degree celcius"))
fahrenheit = (tem * 9/5) + 32
print(fahrenheit)
# Out:
# enter a temperature in the degree celcius25
# 77.0

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
num1 = int (input("enter a first number"))
num2 = int (input("enter a second number"))
num2  =num1
print(num1)
print(num2)
# Out:
# enter a first number20
# enter a second number20
# 20
# 20

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
x1 = int(input("enter a value of x1"))
x2 = int(input("enter a value of x2"))
y1 = int(input("enter a value of y1"))
y2 = int(input("enter a value of y2"))
euclidean_distance = ((x2-x1)**2 + (y2-y1)**2)**0.5
print(euclidean_distance)

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
value_of_principle = int(input("enter a value of principle"))
rate_of_interest = int(input("enter a rate of interest"))
time_period = int(input("enter a time period"))
simple_interest = (value_of_principle*rate_of_interest*time_period)/100
print(simple_interest)
# Out:
# enter a value of principle100
# enter a rate of interest5
# enter a time period5
# 25.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
heads = int(input("enter a number of heads"))
legs = int(input("enter a number of legs"))
dogs = (legs -2*heads)/2
chicken = heads - dogs
print(dogs)
print(chicken)

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n =int(input("enter a number"))
sum =0
for i in range(1,n+1):
   sum +=i**2
print(sum)
# Out:
# enter a number4
# 30

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
H = L = B = 20
h =3
r = 1
vol1 = H**3
vol2 = 3.14*h*r**2
numofglass = vol1/vol2
print(numofglass)
# Out:
# 849.2569002123142
