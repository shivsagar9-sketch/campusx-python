# %% [markdown]
# <a href="https://colab.research.google.com/github/shivsagar9-sketch/campusx-python/blob/main/session1_python_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.python output

# %%
#python is case sensative language
print('hello world')
# Out:
# hello world

# %%
print('salman khan')
# Out:
# salman khan

# %%
print(salman khan)
# Out:
#   File "/tmp/ipykernel_1677/1115953987.py", line 1
#     print(salman khan)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('hello',1,2,5,True)
# Out:
# hello 1 2 5 True

# %%
print('hello',1,2,5,True,sep='/')
# Out:
# hello/1/2/5/True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %% [markdown]
# 2.data type

# %%
#intger
print(8)
#1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
#decimal/float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#text/string
print('hello world')
# Out:
# hello world

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list->  c->Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,))
# Out:
# (1, 2, 3, 4)

# %%
#sets
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
#dictionaries
print({'name':'shiv','gender':'male','weight':64})
# Out:
# {'name': 'shiv', 'gender': 'male', 'weight': 64}

# %%
#type
type(4.6)
# Out:
# float

# %% [markdown]
# 3.variables

# %%
name='shiv'
print(name)
a=5
b=6

print(a+b)
# Out:
# shiv
# 11

# %%
#dynamic typing in this python understand which is the datatype automaticalli ,means is this integer or float or str
a=5
#static typing here its require to define which is the datatype
int (a =5)

# %%
#dynamic binding in this datatypr is chanagable python supports only
a =5
print(a)
a ='shiv'
print(a)


#static binding c /c++ supports
int a =5
# Out:
# 5
# shiv

# %%
a=1
b=2
c=3
print(a,b,c)

# %%
a,b,c=1,2,3 #we can create the variable multiplly in a single line
print(a,b,c)
# Out:
# 1 2 3

# %%
#you can give the same valuse for the different variables
a=b=c=5
print(a,b,c)
# Out:
# 5 5 5

# %% [markdown]
# #comments

# %%
# this is comments
#comments are for the give the instrctions
#compiler = complie the whole into the binary
#interprtor= compile line by line

# %% [markdown]
# #4.keywords and identifier

# %%
  #keywords reserve words 32 in the python

# %%
#identifier =name given to the variable
#you cannot start with the digit
#you can use uppercase lowercase underscore
#identifer cannot be keywords

# %% [markdown]
# #5.user input

# %%
#static vs dynamic
#statis = you can take the information from this college info
#dynamic =you can you input and also get it like ola uber app
input('apna nam bta:')
# Out:
# apna nam bta:shiv
# 'shiv'

# %%
#take the input and store them into variable
fnum =int(input('enter the first number'))#here if there is no int then it will store as the string
snum=int(input('enter the second number'))#string ccan store to the other data type thats why string is built in
#add the num
result=fnum +snum
#print the result
print('result:',result)
print(type(fnum))
# Out:
# enter the first number6
# enter the second number6
# result: 12
# <class 'int'>

# %% [markdown]
# #type conversion

# %%
#implicit python will automstically convrt the data
print(5+5.6)#here python convert int and flot
# Out:
# 10.6

# %%
#explicit
#it is done by using the diff data type
#itis done by using the programmer

# %% [markdown]
# #literals

# %%
a=0b1010 #binary literals
b=100 #decimal literals
c=0o310 #octal literals
d=0x12c #hexadecimal literals


#float literal
float_1=10.5
float_2=1.5e2
float_3=1.5e-3

#complex literal
x=3.14j

print(a,b,c,d)
print(float_1,float_2,float_3)
print(x,x.imag,x.real)

# %% [markdown]
# #string

# %%
string='this is python'
strings="this is python"
char="c"
multiline_str="""this is multiline string with more than one line code."""
unicode = u"\u00dcnic\u00f6de"
raw_str=r"raw \n string"


print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# this is python
# this is python
# c
# this is multiline string with more than one line code.
# Ünicöde
# raw \n string

# %% [markdown]
# #boolean

# %%
a= True +4
b = False +10
print("a:",a)
print("b:",b)
# Out:
# a: 5
# b: 10

# %% [markdown]
# #none

# %%
a= None #for variable declaration
print(a)
# Out:
# None
